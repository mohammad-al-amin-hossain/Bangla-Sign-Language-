# %%
import os
import random
from glob import glob

import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras import preprocessing

# %matplotlib inline

from matplotlib import colors

from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import hsv_to_rgb

from matplotlib import cm
from matplotlib import colors
# Out:
# Using TensorFlow backend.

# %%
camera = cv2.VideoCapture(0)
camera_height = 500
raw_frames_type_1 = []
raw_frames_type_2 = []
raw_frames_type_3 = []
raw_frames_type_4 = []
raw_frames_type_5 = []
raw_frames_type_6 = []

#light_purp = (76, 0, 153)
light_purp = (100, 50, 200)

dark_purp = (204, 153, 255)
# dark_purp = (200, 120, 255)

while(True):
    # read a new frame
    _, frame = camera.read()
    
    # flip the frame
    frame = cv2.flip(frame, 1)
    
    #print (frame.shape)

    # rescaling camera output
    aspect = frame.shape[1] / float(frame.shape[0])
    res = int(aspect * camera_height) # landscape orientation - wide image
    frame = cv2.resize(frame, (res, camera_height))

    # add rectangle
    cv2.rectangle(frame, (300, 75), (650, 425), (255, 0, 127), 2)
    
    #edited part start here:
    frame2 = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    frame3 = cv2.cvtColor(frame2, cv2.COLOR_RGB2HSV)
    frame4 = cv2.inRange(frame3, light_purp, dark_purp)
    frame = cv2.bitwise_and(frame, frame, mask = frame4)
    
    

    # show the frame
    cv2.imshow("Capturing frames", frame)

    key = cv2.waitKey(1)

    # quit camera if 'q' key is pressed
    if key & 0xFF == ord("q"):
        break
    elif key & 0xFF == ord("1"):
        # save the frame
        raw_frames_type_1.append(frame)
        print('1 key pressed - saved TYPE_1 frame')
    elif key & 0xFF == ord("2"):
        # save the frame
        raw_frames_type_2.append(frame)
        print('2 key pressed - Saved TYPE_2 frame')
    elif key & 0xFF == ord("3"):
        # save the frame
        raw_frames_type_3.append(frame)
        print('3 key pressed - Saved TYPE_3 frame')
    elif key & 0xFF == ord("4"):
        # save the frame
        raw_frames_type_4.append(frame)
        print('4 key pressed - Saved TYPE_4 frame')
    elif key & 0xFF == ord("5"):
        # save the frame
        raw_frames_type_5.append(frame)
        print('5 key pressed - Saved TYPE_5 frame')
    elif key & 0xFF == ord("6"):
        # save the frame
        raw_frames_type_6.append(frame)
        print('6 key pressed - Saved TYPE_6 frame')
    
    
camera.release()
cv2.destroyAllWindows()
# Out:
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# 1 key pressed - saved TYPE_1 frame
# ...

# %%
# light_red = (102, 102, 255)
# dark_red = (0, 0, 53) 



# lo_square = np.full((50, 50, 3), light_red, dtype=np.uint8) /255
# do_square = np.full((50, 50, 3), dark_red, dtype=np.uint8) /255

# plt.subplot(1, 2, 1)
# plt.imshow(hsv_to_rgb(lo_square))

# plt.subplot(1, 2, 2)
# plt.imshow(hsv_to_rgb(do_square))





# plt.show()

# %%
import os
save_width = 250
save_height = 250

# light_yellow = (0, 150, 50)
# dark_yellow = (195,255,255)

# light_yellow = (0, 130, 103)
# dark_yellow = (255,182,130)

# light_yellow = (0, 138, 67)
# dark_yellow = (255, 173, 133) 


# light_red = (0, 0, 40)
# dark_red = (102, 102, 255) 

# light_red = (0, 0, 50)
# dark_red = (102, 102, 255)


for i in range(1, 7):
    name = 'E:/pink_signL/data_set/images_type_{}'.format(i)
    os.makedirs(name, exist_ok=True)
    


for i, frame in enumerate(raw_frames_type_1):
    roi = frame[75+2:425-2, 300+2:650-2]
    roi = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)
    roi = cv2.resize(roi, (save_width, save_height))
    
#     plt.imshow(roi)
#     plt.show()
    
#     roi2 = cv2.cvtColor(roi, cv2.COLOR_RGB2HSV)
    
# #     plt.imshow(roi2)
# #     plt.show()
    
#     roi3 = cv2.inRange(roi2, light_yellow, dark_yellow)
    
# #     plt.imshow(roi3)
# #     plt.show()
    
#     roi = cv2.bitwise_and(roi, roi, mask = roi3)
    
#     plt.imshow(roi)
#     plt.show()
    
    cv2.imwrite('E:/pink_signL/data_set/images_type_1/{}.png'.format(i), cv2.cvtColor(roi,cv2.COLOR_BGR2RGB))
    
#     plt.imshow(roi)
#     plt.show()

for i, frame in enumerate(raw_frames_type_2):
    roi = frame[75+2:425-2, 300+2:650-2]
    roi = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)
    roi = cv2.resize(roi, (save_width, save_height))
#     roi2 = cv2.cvtColor(roi, cv2.COLOR_RGB2HSV)
#     roi3 = cv2.inRange(roi2, light_yellow, dark_yellow)
#     roi = cv2.bitwise_and(roi, roi, mask = roi3)
    cv2.imwrite('E:/pink_signL/data_set/images_type_2/{}.png'.format(i), cv2.cvtColor(roi,cv2.COLOR_BGR2RGB))

for i, frame in enumerate(raw_frames_type_3):
    roi = frame[75+2:425-2, 300+2:650-2]
    roi = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)
    roi = cv2.resize(roi, (save_width, save_height))
#     roi2 = cv2.cvtColor(roi, cv2.COLOR_RGB2HSV)
#     roi3 = cv2.inRange(roi2, light_yellow, dark_yellow)
#     roi = cv2.bitwise_and(roi, roi, mask = roi3)
    cv2.imwrite('E:/pink_signL/data_set/images_type_3/{}.png'.format(i), cv2.cvtColor(roi,cv2.COLOR_BGR2RGB))
    
    
for i, frame in enumerate(raw_frames_type_4):
    roi = frame[75+2:425-2, 300+2:650-2]
    roi = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)
    roi = cv2.resize(roi, (save_width, save_height))
#     roi2 = cv2.cvtColor(roi, cv2.COLOR_RGB2HSV)
#     roi3 = cv2.inRange(roi2, light_yellow, dark_yellow)
#     roi = cv2.bitwise_and(roi, roi, mask = roi3)
    cv2.imwrite('E:/pink_signL/data_set/images_type_4/{}.png'.format(i), cv2.cvtColor(roi,cv2.COLOR_BGR2RGB))
    
for i, frame in enumerate(raw_frames_type_5):
    roi = frame[75+2:425-2, 300+2:650-2]
    roi = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)
    roi = cv2.resize(roi, (save_width, save_height))
#     roi2 = cv2.cvtColor(roi, cv2.COLOR_RGB2HSV)
#     roi3 = cv2.inRange(roi2, light_yellow, dark_yellow)
#     roi = cv2.bitwise_and(roi, roi, mask = roi3)
    cv2.imwrite('E:/pink_signL/data_set/images_type_5/{}.png'.format(i), cv2.cvtColor(roi,cv2.COLOR_BGR2RGB))
    
for i, frame in enumerate(raw_frames_type_6):
    roi = frame[75+2:425-2, 300+2:650-2]
    roi = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)
    roi = cv2.resize(roi, (save_width, save_height))
#     roi2 = cv2.cvtColor(roi, cv2.COLOR_RGB2HSV)
#     roi3 = cv2.inRange(roi2, light_yellow, dark_yellow)
#     roi = cv2.bitwise_and(roi, roi, mask = roi3)
    cv2.imwrite('E:/pink_signL/data_set/images_type_6/{}.png'.format(i), cv2.cvtColor(roi,cv2.COLOR_BGR2RGB))
