# %%
import os
import random
from glob import glob

import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras import preprocessing

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
class_names = ['soreo', 'soreya', 'roshuei', 'au', 'ae', 'ou','ka', 'kha', 'ga', 'gha', 'ca', 'cha', 'ja', 'jha', 'Ta', 'Tha', 'Da', 'DHA', 'ta', 'tha', 'da', 'dha', 'na', 'pha','fa', 'bh','va', 'ma', 'ya', 'ra','la', 'sa', 'hah', 'DHAA','onusorgo', 'bishar']

# %%
import os
import random
from glob import glob
from keras import preprocessing

width = 96
height = 96


images_types_1 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/1/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_1.append(x)
    
images_types_2 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/2/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_2.append(x)
    
images_types_3 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/3/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_3.append(x)
    
images_types_4 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/4/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_4.append(x)
    
images_types_5 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/5/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_5.append(x)
    
images_types_6 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/6/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_6.append(x)
    
images_types_7 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/7/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_7.append(x)
    
images_types_8 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/8/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_8.append(x)
    
images_types_9 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/9/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_9.append(x)
    
images_types_10 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/10/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_10.append(x)
    
images_types_11 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/11/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_11.append(x)
    
images_types_12 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/12/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_12.append(x)
    
images_types_13 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/13/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_13.append(x)
    
images_types_14 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/14/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_14.append(x)
    
images_types_15 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/15/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_15.append(x)
    
images_types_16 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/16/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_16.append(x)
    
images_types_17 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/17/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_17.append(x)
    
images_types_18 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/18/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_18.append(x)
    
images_types_19 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/19/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_19.append(x)
    
images_types_20 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/20/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_20.append(x)
    
images_types_21 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/21/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_21.append(x)
    
images_types_22 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/22/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_22.append(x)
    
images_types_23 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/23/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_23.append(x)
    
images_types_24 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/24/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_24.append(x)
    
images_types_25 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/25/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_25.append(x)
    
images_types_26 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/26/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_26.append(x)
    
images_types_27 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/27/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_27.append(x)
    
images_types_28 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/28/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_28.append(x)
    
images_types_29 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/29/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_29.append(x)
    
images_types_30 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/30/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_30.append(x)
    
images_types_31 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/31/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_31.append(x)
    
images_types_32 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/32/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_32.append(x)
    
images_types_33 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/33/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_33.append(x)
    
images_types_34 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/34/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_34.append(x)
    
images_types_35 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/35/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_35.append(x)
    
images_types_36 = []
for image_path in glob('C:/Users/user1/Downloads/isharaLipiDataSet/database/36/*.*'):
    image = preprocessing.image.load_img(image_path,
                                        target_size =(width, height))
    x = preprocessing.image.img_to_array(image)
    images_types_36.append(x)

# %%
X_type_1 = np.array(images_types_1)
X_type_2 = np.array(images_types_2)
X_type_3 = np.array(images_types_3)
X_type_4 = np.array(images_types_4)
X_type_5 = np.array(images_types_5)
X_type_6 = np.array(images_types_6)
X_type_7 = np.array(images_types_7)
X_type_8 = np.array(images_types_8)
X_type_9 = np.array(images_types_9)
X_type_10 = np.array(images_types_10)
X_type_11 = np.array(images_types_11)
X_type_12 = np.array(images_types_12)
X_type_13 = np.array(images_types_13)
X_type_14 = np.array(images_types_14)
X_type_15 = np.array(images_types_15)
X_type_16 = np.array(images_types_16)
X_type_17 = np.array(images_types_17)
X_type_18 = np.array(images_types_18)
X_type_19 = np.array(images_types_19)
X_type_20 = np.array(images_types_20)
X_type_21 = np.array(images_types_21)
X_type_22 = np.array(images_types_22)
X_type_23 = np.array(images_types_23)
X_type_24 = np.array(images_types_24)
X_type_25 = np.array(images_types_25)
X_type_26 = np.array(images_types_26)
X_type_27 = np.array(images_types_27)
X_type_28 = np.array(images_types_28)
X_type_29 = np.array(images_types_29)
X_type_30 = np.array(images_types_30)
X_type_31 = np.array(images_types_31)
X_type_32 = np.array(images_types_32)
X_type_33 = np.array(images_types_33)
X_type_34 = np.array(images_types_34)
X_type_35 = np.array(images_types_35)
X_type_36 = np.array(images_types_36)

# %%
X = np.concatenate((X_type_1, X_type_2, X_type_3, X_type_4, X_type_5, X_type_6, X_type_7, X_type_8, X_type_9, X_type_10, X_type_11, X_type_12, X_type_13, X_type_14, X_type_15, X_type_16, X_type_17, X_type_18, X_type_19, X_type_20, X_type_21, X_type_22, X_type_23, X_type_24, X_type_25, X_type_26, X_type_27, X_type_28, X_type_29, X_type_30, X_type_31, X_type_32, X_type_33, X_type_34, X_type_35, X_type_36), axis=0)
X = X / 255.

X.shape
# Out:
# (1005, 96, 96, 3)

# %%
from keras.utils import to_categorical

y_type_1 = [0 for item in enumerate(X_type_1)]
y_type_2 = [1 for item in enumerate(X_type_2)]
y_type_3 = [2 for item in enumerate(X_type_3)]
y_type_4 = [3 for item in enumerate(X_type_4)]
y_type_5 = [4 for item in enumerate(X_type_5)]
y_type_6 = [5 for item in enumerate(X_type_6)]
y_type_7 = [6 for item in enumerate(X_type_7)]
y_type_8 = [7 for item in enumerate(X_type_8)]
y_type_9 = [8 for item in enumerate(X_type_9)]
y_type_10 = [9 for item in enumerate(X_type_10)]
y_type_11 = [10 for item in enumerate(X_type_11)]
y_type_12 = [11 for item in enumerate(X_type_12)]
y_type_13 = [12 for item in enumerate(X_type_13)]
y_type_14 = [13 for item in enumerate(X_type_14)]
y_type_15 = [14 for item in enumerate(X_type_15)]
y_type_16 = [15 for item in enumerate(X_type_16)]
y_type_17 = [16 for item in enumerate(X_type_17)]
y_type_18 = [17 for item in enumerate(X_type_18)]
y_type_19 = [18 for item in enumerate(X_type_19)]
y_type_20 = [19 for item in enumerate(X_type_20)]
y_type_21 = [20 for item in enumerate(X_type_21)]
y_type_22 = [21 for item in enumerate(X_type_22)]
y_type_23 = [22 for item in enumerate(X_type_23)]
y_type_24 = [23 for item in enumerate(X_type_24)]
y_type_25 = [24 for item in enumerate(X_type_25)]
y_type_26 = [25 for item in enumerate(X_type_26)]
y_type_27 = [26 for item in enumerate(X_type_27)]
y_type_28 = [27 for item in enumerate(X_type_28)]
y_type_29 = [28 for item in enumerate(X_type_29)]
y_type_30 = [29 for item in enumerate(X_type_30)]
y_type_31 = [30 for item in enumerate(X_type_31)]
y_type_32 = [31 for item in enumerate(X_type_32)]
y_type_33 = [32 for item in enumerate(X_type_33)]
y_type_34 = [33 for item in enumerate(X_type_34)]
y_type_35 = [34 for item in enumerate(X_type_35)]
y_type_36 = [35 for item in enumerate(X_type_36)]


y = np.concatenate((y_type_1, y_type_2, y_type_3, y_type_4, y_type_5, y_type_6, y_type_7, y_type_8, y_type_9, y_type_10, y_type_11, y_type_12, y_type_13, y_type_14, y_type_15, y_type_16, y_type_17, y_type_18, y_type_19, y_type_20, y_type_21, y_type_22, y_type_23, y_type_24, y_type_25, y_type_26, y_type_27, y_type_28, y_type_29, y_type_30, y_type_31, y_type_32, y_type_33, y_type_34, y_type_35, y_type_36), axis=0)

y = to_categorical(y, num_classes=len(class_names))

print(y.shape)
# Out:
# (1005, 36)

# %%
from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Flatten, Dense
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import Adam

# default parameters
conv_1 = 16
conv_1_drop = 0.2
conv_2 = 32
conv_2_drop = 0.2
dense_1_n = 1024
dense_1_drop = 0.2
dense_2_n = 512
dense_2_drop = 0.2
lr = 0.001

epochs = 10
batch_size = 32
color_channels = 3

def build_model(conv_1_drop=conv_1_drop, conv_2_drop=conv_2_drop,
                dense_1_n=dense_1_n, dense_1_drop=dense_1_drop,
                dense_2_n=dense_2_n, dense_2_drop=dense_2_drop,
                lr=lr):
    model = Sequential()

    model.add(Convolution2D(conv_1, (3, 3),
                            input_shape=(width, height, color_channels),
                            activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(conv_1_drop))

    model.add(Convolution2D(conv_2, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(conv_2_drop))
        
    model.add(Flatten())
        
    model.add(Dense(dense_1_n, activation='relu'))
    model.add(Dropout(dense_1_drop))

    model.add(Dense(dense_2_n, activation='relu'))
    model.add(Dropout(dense_2_drop))

    model.add(Dense(len(class_names), activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(lr=lr),
                  metrics=['accuracy'])

    return model

# %%
import numpy as np
np.random.seed(1) # for reproducibility

# model with base parameters
model = build_model()

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\user1\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\user1\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        448
# _________________________________________________________________
# ...

# %%
epochs = 30
model.fit(X, y, epochs=epochs)

# epochs = 30
# model.fit(X, y, validation_split= 0.2, epochs=epochs)
# Out:
# WARNING:tensorflow:From C:\Users\user1\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
# 1005/1005 [==============================] - 19s 19ms/step - loss: 4.4908 - acc: 0.0269
# Epoch 2/30
# 1005/1005 [==============================] - 15s 15ms/step - loss: 3.5786 - acc: 0.0428
# Epoch 3/30
# 1005/1005 [==============================] - 15s 15ms/step - loss: 3.4544 - acc: 0.0905
# Epoch 4/30
# 1005/1005 [==============================] - 15s 15ms/step - loss: 2.8616 - acc: 0.1721
# Epoch 5/30
# 1005/1005 [==============================] - 15s 15ms/step - loss: 2.5065 - acc: 0.2617
# Epoch 6/30
# 1005/1005 [==============================] - 15s 15ms/step - loss: 2.1741 - acc: 0.3552
# Epoch 7/30
# 1005/1005 [==============================] - 15s 15ms/step - loss: 1.9666 - acc: 0.4109
# ...

# %%
import pickle

with open ('Bangla_ishara_lipi_without_val_model_pickle', 'wb') as f:
    pickle.dump(model,f)
