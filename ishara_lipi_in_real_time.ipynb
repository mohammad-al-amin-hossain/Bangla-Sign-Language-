# %%
import pickle

with open ('Bangla_ishara_lipi_without_val_model_pickle', 'rb') as f:
    model = pickle.load(f)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\user1\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\user1\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\user1\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
class_names = ['soreo', 'soreya', 'roshuei', 'au', 'ae', 'ou','ka', 'kha', 'ga', 'gha', 'ca', 'cha', 'ja', 'jha', 'Ta', 'Tha', 'Da', 'DHA', 'ta', 'tha', 'da', 'dha', 'na', 'pha','fa', 'bh','va', 'ma', 'ya', 'ra','la', 'sa', 'hah', 'DHAA','onusorgo', 'bishar']

# %%
import os
import random
from glob import glob

import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras import preprocessing

# %matplotlib inline

width = 96
height = 96

camera = cv2.VideoCapture(0)
camera_height = 500




# light_red = (102, 0, 51)
# dark_red = (255, 204, 204)


while(True):
    # read a new frame
    _, frame = camera.read()
    
    # flip the frameq
    frame = cv2.flip(frame, 1)
    
    print (frame.shape)

    # rescaling camera output
    aspect = frame.shape[1] / float(frame.shape[0])
    res = int(aspect * camera_height) # landscape orientation - wide image
    frame = cv2.resize(frame, (res, camera_height))

    # add rectangle
    cv2.rectangle(frame, (300, 75), (650, 425), (240, 100, 0), 2)
    
    get ROI
    roi = frame[75+2:425-2, 300+2:650-2]
    
    
    
    
    
    # parse BRG to RGB
    roi = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)

    # resize
    roi = cv2.resize(roi, (width, height))
    
    # predict!
    roi_X = np.expand_dims(roi, axis=0)

    predictions = model.predict(roi_X)
    type_1_pred, type_2_pred, type_3_pred, type_4_pred, type_5_pred, type_6_pred, type_7_pred, type_8_pred, type_9_pred, type_10_pred, type_11_pred, type_12_pred, type_13_pred, type_14_pred, type_15_pred, type_16_pred, type_17_pred, type_18_pred, type_19_pred, type_20_pred, type_21_pred, type_22_pred, type_23_pred, type_24_pred, type_25_pred, type_26_pred, type_27_pred, type_28_pred, type_29_pred, type_30_pred, type_31_pred, type_32_pred, type_33_pred, type_34_pred, type_35_pred, type_36_pred = predictions[0]

    # add text
    type_1_text = '{}: {}%'.format(class_names[0], int(type_1_pred*100))
    cv2.putText(frame, type_1_text, (2, 70), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 255), 2)

    # add text
    tipe_2_text = '{}: {}%'.format(class_names[1], int(type_2_pred*100))
    cv2.putText(frame, tipe_2_text, (2, 100), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 240, 0), 2)

    
    # add text
    tipe_3_text = '{}: {}%'.format(class_names[2], int(type_3_pred*100))
    cv2.putText(frame, tipe_3_text, (2, 130), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (240, 0, 0), 2)

    # add text
    tipe_4_text = '{}: {}%'.format(class_names[3], int(type_4_pred*100))
    cv2.putText(frame, tipe_4_text, (2, 160), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 240), 2)
    
    # add text
    tipe_5_text = '{}: {}%'.format(class_names[4], int(type_5_pred*100))
    cv2.putText(frame, tipe_5_text, (2, 190), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (51, 25, 0), 2)
    
    # add text
    type_6_text = '{}: {}%'.format(class_names[5], int(type_6_pred*100))
    cv2.putText(frame, type_6_text, (2, 210), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 255), 2)

    # add text
    tipe_7_text = '{}: {}%'.format(class_names[6], int(type_7_pred*100))
    cv2.putText(frame, tipe_7_text, (2, 240), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 240, 0), 2)

    
    # add text
    tipe_8_text = '{}: {}%'.format(class_names[7], int(type_8_pred*100))
    cv2.putText(frame, tipe_8_text, (2, 270), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (240, 0, 0), 2)

    # add text
    tipe_9_text = '{}: {}%'.format(class_names[8], int(type_9_pred*100))
    cv2.putText(frame, tipe_9_text, (2, 300), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 240), 2)
    
    # add text
    tipe_10_text = '{}: {}%'.format(class_names[9], int(type_10_pred*100))
    cv2.putText(frame, tipe_10_text, (2, 330), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (51, 25, 0), 2)
    
    # add text
    type_11_text = '{}: {}%'.format(class_names[10], int(type_11_pred*100))
    cv2.putText(frame, type_11_text, (2, 360), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 255), 2)

    # add text
    tipe_12_text = '{}: {}%'.format(class_names[11], int(type_12_pred*100))
    cv2.putText(frame, tipe_12_text, (2, 390), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 240, 0), 2)

    
    # add text
    tipe_13_text = '{}: {}%'.format(class_names[12], int(type_13_pred*100))
    cv2.putText(frame, tipe_13_text, (2, 420), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (240, 0, 0), 2)

    # add text
    tipe_14_text = '{}: {}%'.format(class_names[13], int(type_14_pred*100))
    cv2.putText(frame, tipe_14_text, (2, 450), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 240), 2)
    
    # add text
    tipe_15_text = '{}: {}%'.format(class_names[14], int(type_15_pred*100))
    cv2.putText(frame, tipe_15_text, (117, 70), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (51, 25, 0), 2)
    
    # add text
    type_16_text = '{}: {}%'.format(class_names[15], int(type_16_pred*100))
    cv2.putText(frame, type_16_text, (117, 100), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 255), 2)

    # add text
    tipe_17_text = '{}: {}%'.format(class_names[16], int(type_17_pred*100))
    cv2.putText(frame, tipe_17_text, (117, 130), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 240, 0), 2)

    
    # add text
    tipe_18_text = '{}: {}%'.format(class_names[17], int(type_18_pred*100))
    cv2.putText(frame, tipe_18_text, (117, 160), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (240, 0, 0), 2)

    # add text
    tipe_19_text = '{}: {}%'.format(class_names[18], int(type_19_pred*100))
    cv2.putText(frame, tipe_19_text, (117, 190), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 240), 2)
    
    # add text
    tipe_20_text = '{}: {}%'.format(class_names[19], int(type_20_pred*100))
    cv2.putText(frame, tipe_20_text, (117, 210), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (51, 25, 0), 2)
    # add text
    type_21_text = '{}: {}%'.format(class_names[20], int(type_21_pred*100))
    cv2.putText(frame, type_21_text, (117, 240), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 255), 2)

    # add text
    tipe_22_text = '{}: {}%'.format(class_names[21], int(type_22_pred*100))
    cv2.putText(frame, tipe_22_text, (117, 270), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 240, 0), 2)
 
    # add text
    tipe_23_text = '{}: {}%'.format(class_names[22], int(type_23_pred*100))
    cv2.putText(frame, tipe_23_text, (117, 300), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (240, 0, 0), 2)

    # add text
    tipe_24_text = '{}: {}%'.format(class_names[23], int(type_24_pred*100))
    cv2.putText(frame, tipe_24_text, (117, 330), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 240), 2)
    
    # add text
    tipe_25_text = '{}: {}%'.format(class_names[24], int(type_25_pred*100))
    cv2.putText(frame, tipe_25_text, (117, 360), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (51, 25, 0), 2)
    # add text
    type_26_text = '{}: {}%'.format(class_names[25], int(type_26_pred*100))
    cv2.putText(frame, type_26_text, (117, 390), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 255), 2)

    # add text
    tipe_27_text = '{}: {}%'.format(class_names[26], int(type_27_pred*100))
    cv2.putText(frame, tipe_27_text, (117, 420), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 240, 0), 2)

    
    # add text
    tipe_28_text = '{}: {}%'.format(class_names[27], int(type_28_pred*100))
    cv2.putText(frame, tipe_28_text, (117, 450), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (240, 0, 0), 2)

    # add text
    tipe_29_text = '{}: {}%'.format(class_names[28], int(type_29_pred*100))
    cv2.putText(frame, tipe_29_text, (117, 480), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 240), 2)
    
    # add text
    type_30_text = '{}: {}%'.format(class_names[29], int(type_30_pred*100))
    cv2.putText(frame, type_30_text, (117, 510), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 255), 2)
    
    # add text
    type_31_text = '{}: {}%'.format(class_names[30], int(type_31_pred*100))
    cv2.putText(frame, type_31_text, (200, 100), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 255), 2)

    # add text
    tipe_32_text = '{}: {}%'.format(class_names[31], int(type_32_pred*100))
    cv2.putText(frame, tipe_32_text, (200, 130), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 240, 0), 2)

    
    # add text
    tipe_33_text = '{}: {}%'.format(class_names[32], int(type_33_pred*100))
    cv2.putText(frame, tipe_33_text, (200, 160), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (240, 0, 0), 2)

    # add text
    tipe_34_text = '{}: {}%'.format(class_names[33], int(type_34_pred*100))
    cv2.putText(frame, tipe_34_text, (200, 190), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 240), 2)
    
    # add text
    tipe_35_text = '{}: {}%'.format(class_names[34], int(type_35_pred*100))
    cv2.putText(frame, tipe_35_text, (200, 210), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (51, 25, 0), 2)
    
    # add text
    type_36_text = '{}: {}%'.format(class_names[35], int(type_36_pred*100))
    cv2.putText(frame, type_36_text, (200, 230), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 255), 2)
    
    
    # show the frame
    cv2.imshow("Test out", frame)

    key = cv2.waitKey(100)

    # quit camera if 'q' key is pressed
    if key & 0xFF == ord("q"):
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# ...
